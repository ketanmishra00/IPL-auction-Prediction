# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns

# %%
df = pd.read_csv(r"D:\ML Projects\IPL mega auction prediction\bats.csv")

# %%
df=df[['Mat','Inns','NO','Runs','Avg','SR','100','50','4s','6s','Eskill','form','country','Prices']]
df.head()
# Out:
#    Mat  Inns  NO  Runs    Avg      SR  100  50   4s   6s  Eskill  form  \
# 0  177   169  26  5412  37.84  131.61    5  36  480  190       2     5
# 1  193   189  28  5368  33.34  137.14    1  38  493  194       1     5
# 2  188   183  28  4898  31.60  130.82    1  36  431  194       2     5
# 3  126   126  17  4706  43.17  142.39    4  44  458  181       2     5
# 4  159   158  21  4579  33.42  124.80    0  37  524   96       1     3
#
#    country  Prices
# 0        0    17.0
# 1        0    11.0
# 2        0    15.0
# 3        1    15.0
# 4        0     5.2

# %%
bazra = df['Avg'] + df['SR'] 
df['bazra']=bazra
df.head()
# Out:
#    Mat  Inns  NO  Runs    Avg      SR  100  50   4s   6s  Eskill  form  \
# 0  177   169  26  5412  37.84  131.61    5  36  480  190       2     5
# 1  193   189  28  5368  33.34  137.14    1  38  493  194       1     5
# 2  188   183  28  4898  31.60  130.82    1  36  431  194       2     5
# 3  126   126  17  4706  43.17  142.39    4  44  458  181       2     5
# 4  159   158  21  4579  33.42  124.80    0  37  524   96       1     3
#
#    country  Prices   bazra
# 0        0    17.0  169.45
# 1        0    11.0  170.48
# 2        0    15.0  162.42
# 3        1    15.0  185.56
# 4        0     5.2  158.22

# %%
df['hundred'] = df['100']
df = df.drop(['100'],axis=1)
df['fifty'] = df['50']
df = df.drop(['50'],axis=1)
df['fours'] = df['4s']
df = df.drop(['4s'],axis=1)
df['sixes'] = df['6s']
df = df.drop(['6s'],axis=1)

# %%
X=df.drop(['Prices'],axis=1)
y=df['Prices']
X[0:5]
# Out:
#    Mat  Inns  NO  Runs    Avg      SR  Eskill  form  country   bazra  hundred  \
# 0  177   169  26  5412  37.84  131.61       2     5        0  169.45        5
# 1  193   189  28  5368  33.34  137.14       1     5        0  170.48        1
# 2  188   183  28  4898  31.60  130.82       2     5        0  162.42        1
# 3  126   126  17  4706  43.17  142.39       2     5        1  185.56        4
# 4  159   158  21  4579  33.42  124.80       1     3        0  158.22        0
#
#    fifty  fours  sixes
# 0     36    480    190
# 1     38    493    194
# 2     36    431    194
# 3     44    458    181
# 4     37    524     96

# %%
from sklearn.model_selection import train_test_split
#X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random state=0)
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size = 0.2,random_state = 0)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit (X_train, y_train)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [-0.00334137 -0.0230149   0.00291105  0.00452191  0.01484665  0.01703612
#   1.24180682  2.00759688 -0.40330552  0.03188277  0.15603679 -0.17901193
#  -0.00664695 -0.01741469]

# %%
from sklearn.metrics import r2_score,mean_squared_error
y_pred = model.predict(X_test)
print("R2-score: %.2f" % r2_score(y_test,y_pred) )
print("mse: %.2f" % mean_squared_error(y_test,y_pred) )
# Out:
# R2-score: 0.69
# mse: 4.78

# %%
import pickle
pickle_out = open("model.pkl","wb")
pickle.dump(model,pickle_out)
pickle_out.close()

# %%
model.predict([[200,190,20,4200,41.00,130,5,25,1,3,0,200,200,90]])
# Out:
# array([20.94726743])
